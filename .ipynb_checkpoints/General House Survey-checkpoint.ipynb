# %% [markdown]
# <h1 style="text-align:center"><strong>The Determinants of Net Household Income in South Africa</strong>: An Exploratory Analysis using General Household Survey Data</h1>
# <p style="text-align:left">Dataset: <a href="#">statsgov</a> </p>

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# * [1. Introduction: General House Survey](#chapter2)
#     * [Data Description](#section_2_1)
#     * [Independent and Response Variable Selection](#section_2_2)
#     * [Data Representation](#section_2_3)
#     * [Research Question](#section_2_4)
#     * [Hypothesis](#section_2_5)
#     * [Variable Description](#section_2_6)
# * [2. Dataset Description](#chapter3)
#     * [House Data](#section_3_1)
#     * [Person Data](#section_3_2)
#     * [Operations Joined Data](#section_3_3)
# * [3. Data Visualization](#chapter4)
#     * [Yearly Plots](#section_4_1)
#     * [Plotting The Hypothesis on The Joined Dataset](#section_4_2)

# %% [markdown]
# <a id="chapter2" name="chapter2"></a>

# %% [markdown]
# <h2 style="text-align:center;"><strong>Introduction</strong>: General House Survey</h2>
# The concern surrounding this research project pertains to the economic status of South African households given their information. The result of the exploration can lead to accurate depictions of contributing factors towards the desolation of poor communities. Earnings are a large factor contributing to the standards of living of a South African civilian. Thus investigating means that offer insight on the <strong>Net Household Income</strong> will, perhaps, illuminate the issues surrounding the well-being of South African constituencies. Given this thought, we aim to investigate how information detailing the circumstances of each household gives inference to the net household income.

# %% [markdown]
# A paper titled <a href="http://www.richtmann.org/journal/index.php/mjss/article/download/11109/10721"> "Socio-Economic Determinants of Household FoodExpenditure in a Low Income Township in South Africa"</a>, published in September 2012. analyzed the impact of selected socio-economic characteristics on food expenditure. Their results were based on a household survey using questionnaires. They explored variables such as; household income; household size; age; employment status; and the educational attainment of the household head.

# %% [markdown]
# A similar study by Slabbert (2009) revealed increasing levels of poverty where 69% of the sampled population in Bophelong was found to be poor. A logistic regression model was used to determine the socio- economic factors affecting the reported impact of high food prices.
# The main objective of this study was to identify and quantify the relationship between household food expenditure and the socio-economic and demographic characteristics of the household. The findings of the study are important to government and industry efforts to understanding the factors that influence food expenditure in a South African township. The article is organized in the following manner. First, the research model is discussed. Second, the empirical results are presented and interpreted. Finally, conclusions are provided.
#
# The research methodology
#
# The data for this study were collected in Bophelong during March 2012. A total of 585 questionnaires were randomly administered in the area through face to face interviews. The survey questionnaire was tested before its distribution and necessary adjustments were made. The questionnaire included information on demographics, respondents’ income and expenditure patterns and their general view about their socio-economic status. Total monthly household food expenditure was of keen interest for this study. Several statistical methods were used to analyze the data using SPSS. A multiple regression model was used to determine the socio-economic factors affecting household food expenditure. The selection of variables likely to influence household food expenditure relies on previous studies by Stewart et al. (2004), McCracken and Brandt (1987), and Redman (1980). The regression model was estimated as follows:
#
# Yt =βXt +εt (1)
#
# Where Yt is unobserved, Xt is vector of explanatory variables, and β is the vector of unknown parameters; and εt is the error term. The following socio-demographic characteristics are therefore hypothesized to influence the amount of money spent on food: (1) total monthly household income, (2) household size, (3) education attainment of the household head, (4) gender, (5) age (6), marital status, and (7) employment status of household head (Table 1).
#
# Table 1: Description of explanatory variables in the regression model
# Variable
# 1. HH_Income
# 2. HH_Size
# 3. Educ_Head
# 4. G_Head
# 5. Age_Head
# 6. MS_Head
# 7. ES_Head
#
#
# Description
# 1. Total gross monthly household income (in Rands)
# 2. Total number of family members in the household
# 3. Formal education of the household head (number of years)
# 4. Gender of the household head (1 for female, 0 for male)
# 5. Age of household head (in years)
# 6. The marital status of the household head (1 for married, 0 for not married) The employment status of the household head (1 for employed, 0 for not)
# 7. The employment status of the household head (1 for employed, 0 for not)
#
#
# Household income is important as it determines how much can be spent on various needs of the household. The quantity and quality of a household’s food consumption pattern are highly correlated with the purchasing power of the household. Household size is meant to account for the effects of household composition on expenditure. It was expected that household size would significantly impact food expenditure. The age of the household head (in years) is selected as an explanatory variable in the study as both younger and older people are assumed to have differences in tastes and preferences for food, eating habits, lifestyles and opportunities to socialize. The gender, employment and marital status of he household head are important to consider as an explanatory variables as the head plays a primary role in food purchasing and can influence the consumption patterns of a household. Formal education of the household head (in number of years) is another explanatory variable selected in this study due to its effect on lifestyles and health-related behavior. Individuals with different levels of education may have different knowledge and perception about diet and health, and consequently may have a different consumption basket.
#
#
# Need to do:
# 1. We need to explore the variable that are highly correlated with the dependent variable
# 2. We need to explore how net income differs accross certain groups e.g male vs female headed households
# 3. Plot the relationship between the averages of the variables

# %% [markdown]
# <a id="chapter2" name="chapter2"></a>

# %% [markdown]
# <a id="section_2_1" name="section_2_1"></a>

# %% [markdown]
# <h3 style="color:lightcoral"><strong>Data Description</strong></h3>
# This dataset was downloaded on 25 May 2021 on the <a href="http://nesstar.statssa.gov.za:8282/metadata/surveys/GHS/">Nesstar</a> website. The dataset constituents comprised of both <strong>household</strong> and <strong>respondent(person)</strong> information. Meaning that the publishers of the data separated each group into separate data files.

# %% [markdown]
# <a id="section_2_2" name="section_2_2"></a>

# %% [markdown]
# <h3 style="color:lightcoral"><strong>Independent and Response Variable Selection</strong></h3>
# The population of the survey consists of all private households in all nine provinces of South Africa and residents in worker's hotels.
# The <i>response variable</i> considered in this research project is the <strong>Net Household Income</strong>(Q812Netincome) for the <i>household</i> against the following independent variables:
#
# <h5 style="color:lightcoral"><strong>House Data</strong></h5>
#
# * <strong>Household Expenditure</strong> (What was the total household expenditure in the previous month) - Categorical
#
# * <strong>Market Value of The Property</strong>( The munipal valuation of the property) - Categorical
#
# * <strong>Head Sex</strong> (What is the head sex of the household) - Discrete
#
# * <strong>Head Age</strong> (What is the head sex of the household) - Continuous
#
# * <strong>Household Income</strong> (totmhinc) - Continuous
#
# <h5 style="color:lightcoral"><strong>Person Data</strong></h5>
#
# * <strong>Employment Status</strong> - Discrete
#
# * <strong>Relationship To Head of Household</strong> ( Q11RELSH ) - Categorical
#
# * <strong>Highest Education Level</strong> (Q15HIEDU) - Discrete

# %% [markdown]
# <a id="section_2_3" name="section_2_3"></a>

# %% [markdown]
# <h3 style="color:lightcoral"><strong>Data Representation: </strong></h3>
# Given the external source, studies have researched and collected various variables on the questions relevant to our research. We have chosen specific variables and explored the potential of others, intending to model a sample of a population. This research hypothesizes that the <strong>Employment Status</strong> of the respondent has a significant determining factor on the net income of the household. Thus the dataset explored is representative of a population

# %% [markdown]
# <a id="section_2_4" name="section_2_4"></a>

# %% [markdown]
# <h3 style="color:lightcoral"><strong>Research Question</strong></h3>
# Given the extraction from the research's excerpt, can we observe explanatory variables that influence the household net income significantly more than the paper considered?

# %% [markdown]
# <a id="section_2_5" name="section_2_5"></a>

# %% [markdown]
# <h3 style="color:lightcoral"><strong>Hypothesis</strong></h3>
# The household head's age has a strong relationship with the household's net income

# %% [markdown]
# <a id="section_2_6" name="section_2_6"></a>

# %% [markdown]
# <h3 style="color:lightcoral"><strong>Data Description</strong></h3>
#
# <h5 style="color:lightcoral"><strong>House Data</strong></h5>
#
# > ##### <strong>Household Expenditure (Q814Exp)</strong>
# What was the total household expenditure in the last month? Include everything that the household and its members spent
# money on, including food, clothing, transport, rent and rates, alcohol and tobacco, school fees, entertainment and any other
# expenses <br/>
# <strong>Range</strong>: 0 - 10 <br/>
# <strong>Value</strong>: 11 - Do Not Know <br/>
#
#
# > ##### <strong>Market Value of The Property (Q58Val)</strong>
# <strong>Range</strong>: 0 - 8  <br/>
# <strong>Value</strong>: 9 - Do Not Know <br/>
# <strong>Value</strong>: 99 - Unspecified <br/>
#
#
# > ##### <strong>Head Sex</strong>
# The sex of the head <br/>
# 1 - Male<br/>
# 2 - Female<br/>
#
#
#
# > ##### <strong>Head Age</strong>
# <strong>Range</strong>: 0 - 110
#
#
# > ##### <strong> Household Income (tothminc)</strong>
# Estimated derived variable of total household income.
# <strong>Range</strong>: 0 - 9999
#
# > ##### <strong>Net Income (Q812Netincome) - Response Variable</strong>
# <strong>Range</strong>: 0-999999
# <h5 style="color:lightcoral"><strong>Person Data</strong></h5>
#
# > ##### <strong>Employment Status (employ_Status1)</strong>
# All individuals aged 15 years and later
# <strong>Range</strong>: 1 - 9
# Values
# 1: Employed
# 2: Unemployed
# 8: Not Applicable
# 9: Unspecified
#
#
#
#
# <blockquote>
#     <h5><strong>Relationship To Head of Household (Q11RELSH)</strong> </h5>
# Relatinship to the head of the household<br>
#     <strong>Range</strong>: 1-9<br>
# <strong>Values</strong><br>
# 1: Head/acting head <br>
# 2: Husband/wife/partner of person <br>
# 3: Son/daughter/stepchild/adopted child of person<br>
# 4: Brother/sister/stepbrother/stepsister of person<br>
# 5: Father/mother/stepfather/stepmother of person <br>
# 6: Grandparent/great grandparent of person<br>
# 7: Grandchild/great grandchild of person<br>
# 8: Other relative (e.g. in-laws or aunt/uncle) of person <br>
# 9: Non-related persons
#  </blockquote><br>
#
#
# <blockquote>
#   <h5><strong>Highest Education Level (Q15HIEDU)</strong></h5>
# Highest completed level of education<br>
#     <strong>Values</strong><br>
# 0: Grade R/0 <br>
# 1: Grade 1/Sub A/Class 1 <br>
# 2: Grade 2/Sub B/Class 2 <br>
# 3: Grade 3/Standard 1/AET 1(Kha Ri Gude, Sanli) <br>
# 4: Grade 4/Standard 2 <br>
# 5: Grade 5/Standard 3/AET 2 <br>
# 6: Grade 6/Standard 4 <br>
# 7: Grade 7/Standard 5/AET 3 <br>
# 8: Grade 8/Standard 6/Form <br>
# 9: Grade 9/Standard 7/Form 2/AET 4  <br>
# 10: Grade 10/Standard 8/ Form <br>
# 11: Grade 11/Standard 9/ Form 4 <br>
# 12: Grade 12/Standard 10/Form 5/Matric (No Exemption) <br>
# 13: Grade 12/Standard 10/Form 5/Matric (Exemption *)  <br>
# 14: NTC 1 N1/NC (V) Level 2 <br>
# 15: NTC 2/N2/ NC (V) Level 3 <br>
# 16: NTC 3/ N3/NC (V)/Level 4 <br>
# 17: N4/NTC 4 <br>
# 18: N5/NTC 5 <br>
# 19: N6/NTC 6 <br>
# 20: Certificate with less than Grade 12/Std <br>
# 21: Diploma with less than Grade 12/Std <br>
# 22: Certificate with Grade 12/Std <br>
# 23: Diploma with Grade 12/Std <br>
# 24: Higher Diploma (Technikon/University of Technology) <br>
# 25: Post Higher Diploma (Technikon/University of Technology Masters, Doctoral) <br>
# 26: Bachelor's Degree  <br>
# 27: Bachelor's Degree and post-graduate diploma  <br>
# 28: Honours Degree <br>
# 29: Higher degree (Master's, Doctorate) <br>
# 30: Other <br>
# 31: Do not know <br>
# 98: No schooling <br>
# 99: Unspecified <br>
# </blockquote>

# %% [markdown]
# <a id="chapter3" name="chapter3"></a>

# %% [markdown]
# <h3 style="text-align:center;color:black"><strong>Data Exploration and Initial Auditing</strong></h3>

# %% [markdown]
# <a id="section_3_1" name="section_3_1"></a>

# %%
import warnings
import matplotlib.gridspec as gridspec
import matplotlib
import seaborn as sns
import pandas as pd
import numpy as np
from IPython.display import display, HTML, Javascript
from matplotlib import pyplot as plt
import data_cleaning as dc
import data_modeling as dm
import data_visualization as dv
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.utils import resample
from statsmodels.stats.outliers_influence import variance_inflation_factor
warnings.filterwarnings('ignore')
from IPython.display import clear_output


# %matplotlib inline
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="section_3_1" name="section_3_1"></a>

# %% [markdown]
# <h5 style="color:lightcoral"><strong>House Data</strong></h5>
#
# > Read in dataset from the years 2015 - 2018
#
# > Select subset of the dataset pertaining to our research question
#
# > Fix letter case mistakes that affect reading input data
#
# > Display the dataset size of each year
#
# > Combine the datasets of different years into one <strong>house</strong> dataset

# %%
dir_ = "Datasets/General House Survey/"

# %%
house_dataset = dir_+"House/GHS-201{}-HOUSE_F1.csv"
(ghs_2015,ghs_2016,ghs_2017,ghs_2018) = [pd.read_csv(house_dataset.format(i)) for i in range(5,9)]
(ghs_2015,ghs_2016,ghs_2017,ghs_2018) = dc.lower_columns(ghs_2015,ghs_2016,ghs_2017,ghs_2018)

# %%
Target = "Q812Netincome"
Columns = ['UqNr','Personnr','Q814Exp','Q58Val','head_sex','head_age','totmhinc','Q812Netincome'] # Original Dataset Columns 
Columns = [str.lower(col) for col in Columns]
Label_Change = ['Unique Number','Person Number','Expenditure','Market Value','Head Sex',"Head Age","Income","Net Income"] # Neatly Named Variables
(ghs_2015,ghs_2016,ghs_2017,ghs_2018) = dc.prune_datasets(Label_Change,Columns,ghs_2015,ghs_2016,ghs_2017,ghs_2018)

# %%
# display
ghs_values = [ghs_2015,ghs_2016,ghs_2017,ghs_2018]
pd_display_ghs = dv.display_records_per_year(ghs_values)
display(pd_display_ghs)
print("Total House Survey Records: ",sum(pd_display_ghs['Number of Records']))
# Out:
#                    Number of Records
# 2015 House Survey              21601
# 2016 House Survey              21218
# 2017 House Survey              21225
# 2018 House Survey              20908
# Total House Survey Records:  84952

# %%
frames = [ghs_2015,ghs_2016,ghs_2017,ghs_2018]
ghs = pd.concat([ghs_2015,ghs_2016,ghs_2017,ghs_2018])

# %% [markdown]
# <a id="section_3_2" name="section_3_2"></a>

# %% [markdown]
# <h5 style="color:lightcoral"><strong>Person Data</strong></h5>
#
# > Read in dataset from the years 2015 - 2018
#
# > Select subset of the dataset pertaining to our research question
#
# > Fix letter case mistakes that affect reading input data
#
# > Display the dataset size of each year
#
# > Combine the datasets of different years into one <strong>person</strong> dataset

# %%
person_dataset = dir_+"Person/GHS-201{}-PERSON_F1.csv"
(phs_2015,phs_2016,phs_2017,phs_2018) = [pd.read_csv(person_dataset.format(i)) for i in range(5,9)]
(phs_2015,phs_2016,phs_2017,phs_2018) = dc.lower_columns(phs_2015,phs_2016,phs_2017,phs_2018)

# %%
phs_values = [phs_2015,phs_2016,phs_2017,phs_2018]
key_string = "201{} Person Survey"
pd_display_phs = dv.display_records_per_year(phs_values,key_string)
display(pd_display_phs)
print("Total Person Survey Records: ",sum(pd_display_phs['Number of Records']))
# Out:
#                    Number of Records
# 2015 House Survey              74449
# 2016 House Survey              72602
# 2017 House Survey              72291
# 2018 House Survey              71137
# Total Person Survey Records:  290479

# %%
Columns = ['UqNr','PersonNR','employ_Status1','Q11RELSH','Q15HIEDU'] # Original Dataset Columns 
Columns = [str.lower(col) for col in Columns]
Label_Change = ['Unique Number','Person Number','Employment Status','Relationship To Head','Education Level'] # Neatly Named Variables
(phs_2015,phs_2016,phs_2017,phs_2018) =dc.prune_datasets(Label_Change,Columns,phs_2015,phs_2016,phs_2017,phs_2018)

# %%
frames = [phs_2015,phs_2016,phs_2017,phs_2018]
phs = pd.concat([phs_2015,phs_2016,phs_2017,phs_2018])

# %% [markdown]
# <a id="section_3_3" name="section_3_3"></a>

# %% [markdown]
# <h4 style="color:lightcoral"><strong>Operations Joined Data</strong></h4>
#
# > Join <strong>House</strong> and <strong>Person</strong> Data based on <i>Unique Number</i> and <i>Person Number</i>
#
# > Drop All <strong>NaN</strong> data types
#
# > Reset the index to an auto incremented integer
#
# > Place the <strong>Net Income</strong> as the last column to distinguish as respondent variable we are trying to predict
#
# > Display the correlation matrix of the <strong>joined dataset</strong>

# %%
house_survey = pd.merge(ghs,phs,on=['Unique Number','Person Number'],how='right').dropna()

# %%
house_survey = house_survey.iloc[:,2:]
house_survey = dc.set_index(house_survey)
house_survey = dc.swap_columns(house_survey,-1,-4)

# %%
house_survey
# Out:
#         Expenditure  Market Value  Head Sex  Head Age  Income  \
# id
# 0               7.0           1.0       1.0      48.0  2640.0
# 1               7.0           1.0       1.0      49.0  7764.0
# 2               7.0           1.0       1.0      50.0  3400.0
# 3               5.0           1.0       1.0      19.0  2900.0
# 4               6.0           1.0       1.0      43.0  2400.0
# ...             ...           ...       ...       ...     ...
# 297696          9.0           7.0       2.0      43.0   330.0
# 297697          9.0           5.0       1.0      51.0  6760.0
# 297698          8.0           1.0       1.0      28.0   330.0
# 297699          5.0           1.0       1.0      40.0  2656.0
# 297700          4.0           1.0       1.0      31.0     0.0
#
#         Education Level  Employment Status  Relationship To Head  Net Income
# id
# 0                     3                  1                     1      2000.0
# ...

# %%
house_survey.describe()
# Out:
#          Expenditure   Market Value       Head Sex       Head Age  \
# count  297701.000000  297701.000000  297701.000000  297701.000000
# mean        7.791724       3.873464       1.437728      48.787354
# std         7.052711       8.347926       0.496108      15.803643
# min         1.000000       1.000000       1.000000       2.000000
# 25%         6.000000       1.000000       1.000000      36.000000
# 50%         8.000000       2.000000       1.000000      48.000000
# 75%         9.000000       4.000000       2.000000      60.000000
# max        99.000000      99.000000       2.000000     110.000000
#
#              Income  Education Level  Employment Status  Relationship To Head  \
# count  2.977010e+05    297701.000000      297701.000000         297701.000000
# mean   8.131295e+05        19.660535           4.063765              1.003886
# std    2.720619e+06        26.208589           3.819833              0.416112
# ...

# %%
# sns.boxplot(house_survey['Net Income'])

# %%
house_survey.corr()
# Out:
#                       Expenditure  Market Value  Head Sex  Head Age    Income  \
# Expenditure              1.000000      0.090289 -0.042743  0.016318  0.026524
# Market Value             0.090289      1.000000 -0.031210 -0.021909  0.047375
# Head Sex                -0.042743     -0.031210  1.000000  0.151527 -0.069197
# Head Age                 0.016318     -0.021909  0.151527  1.000000 -0.068810
# Income                   0.026524      0.047375 -0.069197 -0.068810  1.000000
# Education Level         -0.015802     -0.013420  0.079063  0.259024 -0.036027
# Employment Status       -0.050191     -0.039953  0.218489  0.458190 -0.011164
# Relationship To Head     0.002796      0.002626  0.003003  0.001310 -0.000750
# Net Income               0.285779      0.042387 -0.013439 -0.003215  0.026146
#
#                       Education Level  Employment Status  \
# Expenditure                 -0.015802          -0.050191
# Market Value                -0.013420          -0.039953
# ...

# %% [markdown]
# <a id="chapter4" name="chapter4"></a>

# %%
# sns.heatmap(house_survey.corr())

# %%
sns.distplot(house_survey['Net Income'], kde = True, color = 'green')
# Out:
# <AxesSubplot:xlabel='Net Income', ylabel='Density'>

# %% [markdown]
# <h2 style="text-align:center;color:black"><strong>Data Visualization</strong></h2>

# %% [markdown]
# <a id="section_4_1" name="section_4_1"></a>

# %% [markdown]
# <h4 style="color:lightcoral"><strong>Yearly Plots</strong></h4>
# We are trying to gain understanding of how the data is distributed over time. We generated a series of plots from 2015-2018 that explore the relationship between explanatory and response variable(Net Income)
#
#
# > Collect datasets from years and group them by each year
#
# > Determine the means of their group information
#
# > Display the line plot between the following independent variables and their dependent variable(Net Income)
#
# > Display the scatter plots between the following independent variables and their dependent variable(Net Income)
#
# > Display the bar plots between the following independent variables and their dependent variable(Net Income)

# %%
# ============================== Head Sex

head_sex = ['Male','Female'] # 1: Male , 2: Female
head_sex_title = "Household Mean Net Income Per Head Sex (2015 - 2018)"
head_sex_xlabel = "Year"
head_sex_col = "Head Sex"
head_sex_ylabel = "Mean Net Income"
head_sex_df = dv.group_title_value(ghs_values,head_sex_col,head_sex)


# ============================== Household Expenditure

expenditure = ['R0','R1 - R199','R200 - R399 ','R400 - R799','R800 - R1 199','R1200 - R1799','R1800 - R2499','R2500 - R4999','R5000 - R9999','R10 000 or More']
expenditure_title = "Household Mean Net Income Per Household Expenditure(2015 - 2018)"
expenditure_xlabel = "Year"
expenditure_col = "Expenditure"
expenditure_ylabel = "Mean Net Income"
expenditure_df = dv.group_title_value(ghs_values,expenditure_col,expenditure)


# ============================== Market Value of Property


market_value = ['Less Than R5000','R50k - R250k','R250k - R500k ','R1m - R1.5m','R1.5m - R2m','R2m - R3m','More Than R3m']
market_value_title = "Household Mean Net Income Per Market Value of Property (2015 - 2018)"
market_value_xlabel = "Year"
market_value_col = "Market Value"
market_value_ylabel = "Mean Net Income"
market_value_df = dv.group_title_value(ghs_values,market_value_col,market_value)

# %%
plots = [head_sex_df,market_value_df,expenditure_df]
titles = [head_sex_title,market_value_title,expenditure_title]
xlabels = ["Year","Year","Year"]
categories = [head_sex,market_value,expenditure]
cols = [head_sex_col,market_value_col,expenditure_col]
ylabels = ["Mean Net Income","Mean Net Income","Mean Net Income"]

# %%
sns.set()
sns.set_palette("pastel")

# %%
dv.plot_dataframes(plots,titles,categories,cols)

# %%
ghs_matrix = np.array([[ghs_2015,ghs_2016],[ghs_2017,ghs_2018]])
Title = "201{}: Head Age vs Net Income"

# %%
dv.plot_scatter_matrix(ghs_matrix,Title)

# %%
market_value_df.plot.bar(rot=0,figsize=(25,10))
plt.title("Market Value of Property",fontsize=20)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Mean Net Income",fontsize=15)
# Out:
# Text(0, 0.5, 'Mean Net Income')

# %%
sns.set()
sns.set_palette("Reds", n_colors=2)
sns.set(rc={'figure.figsize':(25,20)})
expenditure_df.plot.bar(rot=0)
plt.title("Yearly Household Expenditure vs Net Income",fontsize=20)
plt.xlabel("Year",fontsize=18)
plt.ylabel("Net Income",fontsize=18)
# Out:
# Text(0, 0.5, 'Net Income')

# %% [markdown]
# <a id="section_4_2" name="section_4_2"></a>

# %% [markdown]
# <h4 style="color:lightcoral"><strong>Plotting The Hypothesis on The Joined Dataset</strong></h4>

# %%
# house_survey[['Head Age','Net Income']].plot.scatter(x='Head Age',y='Net Income')
house_survey_edit = house_survey[['Head Age','Net Income']] #9999999.0
threshold_house_survey = house_survey_edit[house_survey_edit['Net Income'] <= 900000.0 ]
scatter_house = threshold_house_survey[threshold_house_survey['Net Income'] > 0]
scatter_house.plot.scatter(x='Head Age',y='Net Income',figsize=(15,10))
plt.title("Joined Data: Head Age vs Net Income Scatter Plot")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# Text(0.5, 1.0, 'Joined Data: Head Age vs Net Income Scatter Plot')

# %%
regression_columns = ['expenditure','market_value','head_sex','head_age','income','education_level','employment_status','relationship_to_head','net_income']
regression_survey = house_survey.copy()
for col in range(len(regression_columns)):
    regression_survey.rename(columns={house_survey.columns.values[col]:regression_columns[col]},inplace=True)

# %%
regression_survey
# Out:
#         expenditure  market_value  head_sex  head_age  income  \
# id
# 0               7.0           1.0       1.0      48.0  2640.0
# 1               7.0           1.0       1.0      49.0  7764.0
# 2               7.0           1.0       1.0      50.0  3400.0
# 3               5.0           1.0       1.0      19.0  2900.0
# 4               6.0           1.0       1.0      43.0  2400.0
# ...             ...           ...       ...       ...     ...
# 297696          9.0           7.0       2.0      43.0   330.0
# 297697          9.0           5.0       1.0      51.0  6760.0
# 297698          8.0           1.0       1.0      28.0   330.0
# 297699          5.0           1.0       1.0      40.0  2656.0
# 297700          4.0           1.0       1.0      31.0     0.0
#
#         education_level  employment_status  relationship_to_head  net_income
# id
# 0                     3                  1                     1      2000.0
# ...

# %%
regression_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297701 entries, 0 to 297700
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   expenditure           297701 non-null  float64
#  1   market_value          297701 non-null  float64
#  2   head_sex              297701 non-null  float64
#  3   head_age              297701 non-null  float64
#  4   income                297701 non-null  float64
#  5   education_level       297701 non-null  int64
#  6   employment_status     297701 non-null  int64
#  7   relationship_to_head  297701 non-null  int64
#  8   net_income            297701 non-null  float64
# dtypes: float64(6), int64(3)
# memory usage: 22.7 MB

# %%
X = regression_survey.drop('net_income', axis = 1)
y = regression_survey.net_income

# %%
X_categorical_cols = X.drop(['head_age','income'], axis = 1).columns
X_categorical_cols
# Out:
# Index(['expenditure', 'market_value', 'head_sex', 'education_level',
#        'employment_status', 'relationship_to_head'],
#       dtype='object')

# %%
def convert_cols_to_int64(data):
    float64cols = []
    for col in data.columns:
        if (data[col].dtype) == 'float64':
            float64cols.append(col)
            print(col)
            print((data[col].dtype))
    data[float64cols] = data[float64cols].astype('int64')
    return data

# %%
X[X_categorical_cols] = convert_cols_to_int64(X[X_categorical_cols])
X.info()
# Out:
# expenditure
# float64
# market_value
# float64
# head_sex
# float64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 297701 entries, 0 to 297700
# Data columns (total 8 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   expenditure           297701 non-null  int64
#  1   market_value          297701 non-null  int64
#  2   head_sex              297701 non-null  int64
#  3   head_age              297701 non-null  float64
#  4   income                297701 non-null  float64
#  5   education_level       297701 non-null  int64
#  6   employment_status     297701 non-null  int64
#  7   relationship_to_head  297701 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 20.4 MB

# %%
dummied_X =  pd.get_dummies(X, columns = X_categorical_cols, drop_first = False)
dummied_X
# Out:
#         head_age  income  expenditure_1  expenditure_2  expenditure_3  \
# id
# 0           48.0  2640.0              0              0              0
# 1           49.0  7764.0              0              0              0
# 2           50.0  3400.0              0              0              0
# 3           19.0  2900.0              0              0              0
# 4           43.0  2400.0              0              0              0
# ...          ...     ...            ...            ...            ...
# 297696      43.0   330.0              0              0              0
# 297697      51.0  6760.0              0              0              0
# 297698      28.0   330.0              0              0              0
# 297699      40.0  2656.0              0              0              0
# 297700      31.0     0.0              0              0              0
#
#         expenditure_4  expenditure_5  expenditure_6  expenditure_7  \
# id
# ...

# %%
dummied_X.columns
# Out:
# Index(['head_age', 'income', 'expenditure_1', 'expenditure_2', 'expenditure_3',
#        'expenditure_4', 'expenditure_5', 'expenditure_6', 'expenditure_7',
#        'expenditure_8', 'expenditure_9', 'expenditure_10', 'expenditure_11',
#        'expenditure_12', 'expenditure_99', 'market_value_1', 'market_value_2',
#        'market_value_3', 'market_value_4', 'market_value_5', 'market_value_6',
#        'market_value_7', 'market_value_8', 'market_value_9', 'market_value_99',
#        'head_sex_1', 'head_sex_2', 'education_level_0', 'education_level_1',
#        'education_level_2', 'education_level_3', 'education_level_4',
#        'education_level_5', 'education_level_6', 'education_level_7',
#        'education_level_8', 'education_level_9', 'education_level_10',
#        'education_level_11', 'education_level_12', 'education_level_13',
#        'education_level_14', 'education_level_15', 'education_level_16',
# ...

# %%
cols_to_drop = ['education_level_31','education_level_99','market_value_9','market_value_99','expenditure_11']
final_dummied_X = dummied_X.drop(cols_to_drop, axis = 1)
final_dummied_X
# Out:
#         head_age  income  expenditure_1  expenditure_2  expenditure_3  \
# id
# 0           48.0  2640.0              0              0              0
# 1           49.0  7764.0              0              0              0
# 2           50.0  3400.0              0              0              0
# 3           19.0  2900.0              0              0              0
# 4           43.0  2400.0              0              0              0
# ...          ...     ...            ...            ...            ...
# 297696      43.0   330.0              0              0              0
# 297697      51.0  6760.0              0              0              0
# 297698      28.0   330.0              0              0              0
# 297699      40.0  2656.0              0              0              0
# 297700      31.0     0.0              0              0              0
#
#         expenditure_4  expenditure_5  expenditure_6  expenditure_7  \
# id
# ...

# %%
final_dummied_X['net_income'] = y
initial_data = final_dummied_X.copy()
initial_data
# Out:
#         head_age  income  expenditure_1  expenditure_2  expenditure_3  \
# id
# 0           48.0  2640.0              0              0              0
# 1           49.0  7764.0              0              0              0
# 2           50.0  3400.0              0              0              0
# 3           19.0  2900.0              0              0              0
# 4           43.0  2400.0              0              0              0
# ...          ...     ...            ...            ...            ...
# 297696      43.0   330.0              0              0              0
# 297697      51.0  6760.0              0              0              0
# 297698      28.0   330.0              0              0              0
# 297699      40.0  2656.0              0              0              0
# 297700      31.0     0.0              0              0              0
#
#         expenditure_4  expenditure_5  expenditure_6  expenditure_7  \
# id
# ...

# %%
formula = "net_income ~ head_sex_1 + head_sex_2"
initial_data_gender_model = smf.ols(formula, initial_data).fit(fit_intercept=False)
print(initial_data_gender_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             net_income   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     53.78
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):           2.25e-13
# Time:                        04:39:15   Log-Likelihood:            -4.3618e+06
# No. Observations:              297701   AIC:                         8.724e+06
# Df Residuals:                  297699   BIC:                         8.724e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.965e+04    687.622     43.119      0.000    2.83e+04     3.1e+04
# ...

# %%
y.name
# Out:
# 'net_income'

# %%
X.columns
# Out:
# Index(['expenditure', 'market_value', 'head_sex', 'head_age', 'income',
#        'education_level', 'employment_status', 'relationship_to_head'],
#       dtype='object')

# %%
initial_data_without_response = initial_data.drop(y.name, axis = 1)
response = y.name
formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(initial_data_without_response.columns))
initial_data_model_all_variables = smf.ols(formula, initial_data).fit(fit_intercept = False)
print(initial_data_model_all_variables.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             net_income   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.089
# Method:                 Least Squares   F-statistic:                     442.8
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):               0.00
# Time:                        04:39:16   Log-Likelihood:            -4.3479e+06
# No. Observations:              297701   AIC:                         8.696e+06
# Df Residuals:                  297634   BIC:                         8.697e+06
# Df Model:                          66
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                2.342e+04   2.57e+04      0.912      0.362   -2.69e+04    7.38e+04
# ...

# %%
from sklearn.model_selection import train_test_split
final_X = initial_data.drop('net_income', axis = 1)
final_y = initial_data['net_income']
X_train, X_test, y_train, y_test = train_test_split(final_X, final_y, train_size = 0.7,
                                                    test_size=0.3, random_state = 100)
# train_data, test_data = train_test_split(initial_data, test_size = 0.2)

# %%
y_train.head()
# Out:
# id
# 17527     50000.0
# 217055     1200.0
# 257783     5000.0
# 276860    20000.0
# 175899     5000.0
# Name: net_income, dtype: float64

# %%
X_train.head()
# Out:
#         head_age     income  expenditure_1  expenditure_2  expenditure_3  \
# id
# 17527       42.0    11660.0              0              0              0
# 217055      21.0  9999999.0              0              0              0
# 257783      59.0     2590.0              0              0              0
# 276860      49.0    35000.0              0              0              0
# 175899      43.0     1600.0              0              0              0
#
#         expenditure_4  expenditure_5  expenditure_6  expenditure_7  \
# id
# 17527               0              0              0              0
# 217055              0              0              1              0
# 257783              0              0              1              0
# 276860              0              0              0              0
# 175899              0              0              0              1
#
#         expenditure_8  ...  employment_status_9  relationship_to_head_1  \
# id                     ...
# ...

# %%
def combine_data(X,y):
    combined_data = pd.DataFrame(y)
    combined_data[X.columns] = X
    return combined_data

# %%
train_data = combine_data(X_train, y_train)
test_data = combine_data(X_test, y_test)

# %% [markdown]
# ## Variable and Model Selection
#
# From our given dataset, there are a large number of variables to choose from. As we have seen from the above models, including all variables we run into multicollinearity. Including a restricted number we may have subjective models. Thus the choice of which model to include is dependent on the predictive ability of the entire model.
#  Common measures to assess the predictive ability of the model are:
# * AIC, AICc, BIC
# * $R^2$ and adj-$R^2$
#
#
# #### Stepwise Regression
# Since we have a large number of potential predictors, there are a lot of subsets to go through. Thus, we use stepwise regression procedures. These procedures find a good model, but it may not be the best model.
#
# 1) Check for multicollinearity:
# This is when the predictores are linearly dependent, thus at least one predictor is redundatant. This causes problems as we have unstable samples. We employ Variance Inflation Factors(VIF) to check for multicollinearity.Interpretation of the VIF is  variance of coefficient estimator is inflated by a factor of VIF in comparison to if the variable was not correlated. We will drop thenredundant feature
#
# 2) Backward Regression:
# start with all variables and measure the p value, then remove at a variable time and measure p value. Then choose model with best pvalue and iterate through the last two steps
#
# 3) Forward Regression
# start with model that has only the intercept then include one variable at a time and measure adjusted $R^2$. Choose model with best $R^2$ and iterate through the last two steps

# %%
def calculate_vif_(X, thresh):
    """Calculation of VIFs to reduce multicollinearity problems.

    Parameters:
    -----------
    X : pandas DataFrame with all possible predictors but
    not the response variable.

    thresh: integer, threshold by which to exclude variables
    for dataset

    Returns:
    --------
    remaining: list of variable names that still remain in 
               the dataset

    """
    cols = X.columns
    variables = np.arange(X.shape[1])
    dropped=True
    while dropped:
        dropped=False
        c = X[cols[variables]].values
        vif = [variance_inflation_factor(c, ix) for ix in np.arange(c.shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X[cols[variables]].columns[maxloc] + '\' at index: ' + str(maxloc))
            variables = np.delete(variables, maxloc)
            dropped=True

#     print('Remaining variables:')
#     print(X.columns[variables])
    remaining=cols[variables]
    return remaining

# %%
def remove_inflated_variables(train_X, sample_size, thresh = 10):
    """Calculation of VIFs to reduce multicollinearity problems
    using a subset of the data

    Parameters:
    -----------
    train_data : pandas DataFrame with all possible predictors and
    without the response variable

    sample_size: integer, size of the sample used to estimate the
    VIFs

    Returns:
    --------
    remaining: list of variable names that still remain in 
               the dataset

    """
#     resampled_train = resample(train_data ,n_samples = sample_size)
#     train_X = train_data.drop('net_income', axis = 1)
    remaining = calculate_vif_(train_X, thresh)
    return remaining

# %%
remaining = remove_inflated_variables(X_train, 5000, thresh = 5)
remaining
# Out:
# dropping 'head_sex_1' at index: 22
# dropping 'employment_status_1' at index: 55
# dropping 'relationship_to_head_1' at index: 58
# dropping 'head_age' at index: 0
# dropping 'expenditure_8' at index: 8
# Index(['income', 'expenditure_1', 'expenditure_2', 'expenditure_3',
#        'expenditure_4', 'expenditure_5', 'expenditure_6', 'expenditure_7',
#        'expenditure_9', 'expenditure_10', 'expenditure_12', 'expenditure_99',
#        'market_value_1', 'market_value_2', 'market_value_3', 'market_value_4',
#        'market_value_5', 'market_value_6', 'market_value_7', 'market_value_8',
#        'head_sex_2', 'education_level_0', 'education_level_1',
#        'education_level_2', 'education_level_3', 'education_level_4',
#        'education_level_5', 'education_level_6', 'education_level_7',
#        'education_level_8', 'education_level_9', 'education_level_10',
#        'education_level_11', 'education_level_12', 'education_level_13',
# ...

# %%
train_X = X_train[remaining]
train_y = y_train
train_y
# Out:
# id
# 17527     50000.0
# 217055     1200.0
# 257783     5000.0
# 276860    20000.0
# 175899     5000.0
#            ...
# 212912     2500.0
# 65615      1000.0
# 253799     5000.0
# 210755    30000.0
# 56088     12000.0
# Name: net_income, Length: 208390, dtype: float64

# %%
# temp_y = list(train_y)
train_X
# Out:
#            income  expenditure_1  expenditure_2  expenditure_3  expenditure_4  \
# id
# 17527     11660.0              0              0              0              0
# 217055  9999999.0              0              0              0              0
# 257783     2590.0              0              0              0              0
# 276860    35000.0              0              0              0              0
# 175899     1600.0              0              0              0              0
# ...           ...            ...            ...            ...            ...
# 212912     2620.0              0              0              0              0
# 65615      1980.0              0              0              0              0
# 253799     1410.0              0              0              0              0
# 210755    22500.0              0              0              0              0
# 56088      5300.0              0              0              0              0
#
# ...

# %%
def stepwise_selection(X, y, 
                       initial_list=[], 
                       threshold_in=0.001, 
                       threshold_out = 0.05, 
                       verbose=True):
    """ Perform a forward-backward feature selection 
    based on p-value from statsmodels.api.OLS
    Parameters:
        X - pandas.DataFrame with candidate features
        y - list-like with the target
        initial_list - list of features to start with (column names of X)
        threshold_in - include a feature if its p-value < threshold_in
        threshold_out - exclude a feature if its p-value > threshold_out
        verbose - whether to print the sequence of inclusions and exclusions
    Returns: list of selected features 
    """
    included = list(initial_list)
    while True:
        changed=False
        # forward step
        excluded = list(set(X.columns)-set(included))
        new_pval = pd.Series(index=excluded)
        for new_column in excluded:
            model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included+[new_column]]))).fit()
            new_pval[new_column] = model.pvalues[new_column]
        best_pval = new_pval.min()
        if best_pval < threshold_in:
            best_feature = new_pval.idxmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add  {:30} with p-value {:.6}'.format(best_feature, best_pval))

        # backward step
        model = sm.OLS(y, sm.add_constant(pd.DataFrame(X[included]))).fit()
        # use all coefs except intercept
        pvalues = model.pvalues.iloc[1:]
        worst_pval = pvalues.max() # null if pvalues is empty
        if worst_pval > threshold_out:
            changed=True
            worst_feature = pvalues.idxmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature, worst_pval))
        if not changed:
            break
    return included

# %%
def backward_selction(X,y):
    cols= list(X.columns)
    pmax = 1
    verbose=True
    while (len(cols)>0):
        p=[]
        x_1=pd.DataFrame(X[cols])
        x_1= sm.add_constant(x_1)
        model= sm.OLS(y,x_1).fit()
        p= pd.Series(model.pvalues.values[1:],index=cols)
        pmax= max(p)
        feature_with_p_max=p.idxmax()
        if(pmax>0.05):
            cols.remove(feature_with_p_max)
            print('Drop {:30} with p-value {:.6}'.format(feature_with_p_max, pmax))
        else:
            break
    selected_features= cols
    selected_X = X[selected_features]
    selected_y = y
    
    selected_data = combine_data(selected_X,selected_y)
    return selected_data

# %%
selected_train_data = backward_selction(train_X,train_y)
# Out:
# Drop education_level_2              with p-value 0.99845
# Drop relationship_to_head_99        with p-value 0.993014
# Drop relationship_to_head_2         with p-value 0.990241
# Drop education_level_1              with p-value 0.943755
# Drop education_level_15             with p-value 0.930081
# Drop relationship_to_head_8         with p-value 0.929777
# Drop relationship_to_head_9         with p-value 0.818342
# Drop relationship_to_head_4         with p-value 0.786036
# Drop education_level_27             with p-value 0.727613
# Drop employment_status_9            with p-value 0.685297
# Drop expenditure_3                  with p-value 0.661281
# Drop education_level_20             with p-value 0.660913
# Drop expenditure_2                  with p-value 0.659784
# Drop education_level_13             with p-value 0.637938
# Drop market_value_3                 with p-value 0.625246
# Drop education_level_98             with p-value 0.614946
# ...

# %%
import statsmodels.formula.api as smf

def forward_selected(data, response):
    """Linear model designed by forward selection.

    Parameters:
    -----------
    data : pandas DataFrame with all possible predictors and response

    response: string, name of response column in data

    Returns:
    --------
    model: an "optimal" fitted statsmodels linear model
           with an intercept
           selected by forward selection
           evaluated by adjusted R-squared
    """
    remaining = set(data.columns)
    remaining.remove(response)
    selected = []
    current_score, best_new_score = 0.0, 0.0
    count=0
    while remaining and current_score == best_new_score:
        scores_with_candidates = []
        for candidate in remaining:
#             print('Candidate: {:}'.format(candidate))
            formula = "{} ~ {} + 1".format(response,
                                           ' + '.join(selected + [candidate]))
            score = smf.ols(formula, data).fit(fit_intercept=False).rsquared_adj
            scores_with_candidates.append((score, candidate))
        count+=1
        scores_with_candidates.sort()
        best_new_score, best_candidate = scores_with_candidates.pop()
        if ((current_score < best_new_score) or (count>=20)):
            print('Adding: {}'.format(best_candidate))
            count=0
            remaining.remove(best_candidate)
            selected.append(best_candidate)
            current_score = best_new_score
    formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(selected))
    model = smf.ols(formula, data).fit(fit_intercept=False)
    return model

# %%
model = forward_selected(selected_train_data, 'net_income')
# Out:
# Adding: expenditure_99
# Adding: expenditure_12
# Adding: market_value_7
# Adding: income
# Adding: market_value_8
# Adding: head_sex_2
# Adding: education_level_29
# Adding: expenditure_5
# Adding: market_value_4
# Adding: expenditure_10
# Adding: employment_status_8
# Adding: expenditure_9
# Adding: relationship_to_head_3
# Adding: education_level_28
# Adding: education_level_26
# Adding: education_level_8
# Adding: education_level_12
# Adding: market_value_2
# Adding: market_value_1

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             net_income   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.086
# Method:                 Least Squares   F-statistic:                     1035.
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):               0.00
# Time:                        04:43:03   Log-Likelihood:            -3.0414e+06
# No. Observations:              208390   AIC:                         6.083e+06
# Df Residuals:                  208370   BIC:                         6.083e+06
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                3.37e+04   2819.912     11.950      0.000    2.82e+04    3.92e+04
# ...

# %%
def bootstrapping(train_data, simulations, sample_size):
    """Use random sampling to collect the features that are most often
    used for the optimal regression model 

    Parameters:
    -----------
    data : pandas DataFrame with all possible predictors and
    the response variable
    
    simulations : integer, the number of samples that must be taken
    from the data

    sample_size: integer, size of the sample used to fit the
    regression model

    Returns:
    --------
    resulting_models: list of the models and model parameters fit 
    for each sample

    """
    temp_X = train_data.drop('net_income', axis = 1)
    temp_y = train_data['net_income']
    optimal_models = []
    for i in range(0,simulations):
        
        print('Starting iteration: {:}'.format(i))
        
        data_sampled = resample(train_data, n_samples=sample_size)
        remaining = remove_inflated_variables(data_sampled, sample_size=sample_size, thresh=5)
    
        
        X = train_data[remaining]
        y = train_data['net_income']

        result_data = backward_selction(X, y) 
#         result.append('mon_income')
        
        model = forward_selected(result_data, 'net_income')
        choosen=[]
        choosen=[model,model.params,model.bse,model.pvalues,model.conf_int(),model.condition_number,model.rsquared_adj]
        optimal_models.append(choosen)
        print('Finish iteration: {:}'.format(i))
    return optimal_models

# %%
train_data_models = bootstrapping(train_data, 30, 5000)
# Out:
# Starting iteration: 0
# dropping 'head_sex_1' at index: 23
# dropping 'employment_status_1' at index: 56
# dropping 'relationship_to_head_1' at index: 59
# dropping 'head_age' at index: 1
# dropping 'expenditure_8' at index: 9
# Drop education_level_28             with p-value 0.998744
# Drop education_level_24             with p-value 1.0
# Drop relationship_to_head_5         with p-value 0.99678
# Drop relationship_to_head_99        with p-value 0.995138
# Drop relationship_to_head_2         with p-value 0.997924
# Drop relationship_to_head_9         with p-value 0.994417
# Drop market_value_8                 with p-value 1.0
# Drop market_value_4                 with p-value 1.0
# Drop relationship_to_head_7         with p-value 0.99496
# Drop education_level_22             with p-value 0.99524
# Drop education_level_19             with p-value 0.990689
# Drop market_value_3                 with p-value 0.99855
# Drop education_level_16             with p-value 0.997538
# ...

# %%
for model in train_data_models:
    print(model[0].summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             net_income   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     3232.
# Date:                Sun, 20 Jun 2021   Prob (F-statistic):               0.00
# Time:                        05:27:30   Log-Likelihood:            -3.0415e+06
# No. Observations:              208390   AIC:                         6.083e+06
# Df Residuals:                  208383   BIC:                         6.083e+06
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2.793e+04   1665.712     16.768      0.000    2.47e+04    3.12e+04
# ...

# %%
def most_common_features(models,adj_R_squared,iters_fraction):
    """Use model list obtained from resampling procedure and 
    select the features that were used in the best models

    Parameters:
    -----------
    models : list of the models and model parameters fit 
    for each sample

    adj_R_squared: float, the threshold value for the R-squared adjusted 
    value for a model to be included in feature list
    
    iters_fraction : integer, minimum number of models in which a 
    feature must be included for it to be included in the feature 
    list

    Returns:
    --------
    valid: list of the features that meet all the necessary
    criteria to be included in the final model

    """
    features = {}
    for i in range(len(models)):
        if (models[i][6] > adj_R_squared):
            feat = list(models[i][1].index)
            for f in feat:
                try:
                    features[f]+=1
                except:
                    features[f]=1
    valid = []
    for feat,value in features.items():
        print(value)
        if ((value >= iters_fraction) and (feat != 'Intercept')):
            valid.append(feat)
#         valid=valid[1:]
    return valid

# %%
model.rsquared_adj
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-4b04d3a01e5b> in <module>
# ----> 1 model.rsquared_adj
#
# AttributeError: 'list' object has no attribute 'rsquared_adj'

# %%
adj_R_squared = model.rsquared_adj
adj_R_squared = round(adj_R_squared, 3)
print(adj_R_squared)
assert adj_R_squared == 0.086 , ("Wrong")
models_common_features = most_common_features(train_data_models, adj_R_squared - 0.010, 1)# use value found in model for adj_R_squared
models_common_features
# Out:
# 0.086
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# ['expenditure_99',
#  'expenditure_12',
#  'expenditure_10',
#  'expenditure_9',
#  'market_value_1',
#  'expenditure_1']

# %%
response = 'net_income'
formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(models_common_features))
chosen_model = smf.ols(formula, train_data).fit(fit_interept=False)
print(chosen_model.summary())

# %% [markdown]
# ### Residual Analysis
#
# Now that we have selected the optimal model, we analyse the residuals and check if we met the assumption of the model.
# We perform the following four plots to check for the following:<br>
# 1) heteroskedasticity<br>
# 2) if residuals are related to predictors<br>
# 3)  if residuals are related to dependent variable<br>
#
# If these assuptions are not satisfied the the least square estimate is not efficient. The estimated will be biased at the statistical tests will be misleading.

# %%
import matplotlib as mpl
mpl.rcParams['agg.path.chunksize']=10000

# figure window
fig = plt.figure(figsize=[16,16]);
    # subplots
ax1 = plt.subplot2grid((2,2), (0,0), colspan=2)

#residual plot
chosen_model.resid.plot(ax=ax1)
plt.suptitle('Residuals from Linear regression model', size = 20);
plt.subplots_adjust(top=0.9)

# %%
from statsmodels.graphics.tsaplots import month_plot, plot_acf, plot_pacf
# figure window
fig = plt.figure(figsize=[10,6]);
ax1 = plt.subplot2grid((2,2), (0,0), colspan=2)
# ACF
plot_acf(chosen_model.resid, ax=ax1, lags=50, zero=False)    
plt.subplots_adjust(top=0.9)

# %%
# figure window
fig = plt.figure(figsize=[10,6]);
# residual histogram
sns.distplot(chosen_model.resid, kde=True, rug=True, hist = True)
# tight format
fig.tight_layout()

# %%
ax = plt.scatter(y = chosen_model.resid, x = chosen_model.predict())
plt.xlabel('Fitted');
plt.ylabel('Residuals');
plt.show()

# %%
response = 'net_income'
formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(common_features))
validation_model = smf.ols(formula, test_data).fit(fit_interept=False)
print(validation_model.summary())

# %% [markdown]
# # <center> Hypothesis Testing </center><br>

# %% [markdown]
# **P-value approach**
# <br>
# This is the probability of finding observed or more extreme results given that the null hypothesis is true. The significance level $\alpha$ is a pre-chosen probability that we use in the as the benchmark. If the calculated pvalue is less than the significance level then we fail to accept the null hypothesis. This means that we accept that our sample gives reasonable evidence to support the alternative hypothesis.<br>
#
# **The F-test**<br>
# measures if the predictive ability of the model is due to statistical noise or the predictors. This is the test of overall significance.
# The F-test tests if the current combination of variables offers better predictive ability than the mean.
# Test:
# $$ H_0: \beta_0 = \beta_1 = \dots = \beta_m = 0 \\ H_1: \beta_i \neq 0 \ \text{for at least one $i$} $$
# This is tested using the F-statistic which compares the explained variance against the unexplained variance:
# $$ \begin{aligned} F^{*} &\propto \frac{\text{explained variation}}{\text{unexplained variation}} \end{aligned} $$
# If $F^{*}$ is large (**equivalently, p-value is small**) reject $H_0$
#
#
# **Methodology**<br>
# 1) We apply bootstrapping procedure, this method enables us to simulate the distribution of the statistic. We use the estimated p-values that we obtain from fitting the model for each predictor. Then proceed to check if each of the estimated pvalues (for the each individual regressors) exceed the significance level. Then for each $x_i$ we proceed to calculate the p value, using the following formula:
# $$ \begin{aligned}\frac{count}{number of bootstraps}\end{aligned} $$
# 2) To find the F-value, we repeat the bootstaping procedure and store the f-statistic from the model at every simulation. Then we proceed to sum all the f-statistic and divide it by the number of bootstraps. By this we obtain the mean f-statistic of the model.
#
# **Assumption:**<br>
# Assume error has normal distribution

# %%
def chosen_model_coefficients(common_feautures, data, sample_size, iters):
    """Fit the regression models using the selected features
    and samples from the data to get a distribution of the regression 
    coefficients for the different features

    Parameters:
    -----------
    common_feautures: list of the features that meet all the necessary
    criteria to be included in the final model

    data : pandas DataFrame with all possible predictors and
    the response variable
    
    sample_size: integer, size of the sample used to fit the
    regression model
    
    iters : integer, the number of samples that must be taken
    from the data

    Returns:
    --------
    resulting_coefficients: list of regression coeffient values for each 
    feature obtained from each model fit with each sample

    """
    response='net_income'
    formula = "{} ~ {} + 1".format(response,
                                   ' + '.join(common_features))
    resulting_coefficients=[]
    for i in range(0,iters):
        sample_train=resample(data,n_samples=sample_size)
        sample_dummy_mod = sample_train.copy()
        model = smf.ols(formula, sample_dummy_mod).fit()
        resulting_coefficients.append([model.params,model.bse,model.conf_int()])
    return resulting_coefficients

# %%
coefs = chosen_model_coefficients(common_features, train_data, 5000, 2000)
coefs

# %%
def get_conf_intervals(coefficients_list,valid):
    """Get the mean and confidence intervals for the regression coefficients
    of each feature

    Parameters:
    -----------
    coefficients: list of regression coeffient values for each 
    feature obtained from each model fit with each sample

    valid : list of the features that meet all the necessary
    criteria to be included in the final model

    Returns:
    --------
    mean_conf_intv: mean and confidence intervals for each feature
    in selected feature list
    """
    ranges=[]
    
    for i in range(1,len(valid)+1):
        coeffs_param=[]
        for j in range(0,len(coefficients_list)):
            coeffs_param.append(coefficients_list[j][0][i])
        ranges.append(coeffs_param)
    mean_conf_intv=[]
    for k in range(0,len(valid)):
        test=np.array(ranges[k])
        mean_param=test.mean()
        test.sort()
        conf_intv=np.percentile(test,[2.5,97.5])
        mean_conf_intv.append([mean_param,conf_intv])
    return mean_conf_intv

# %%
conf_intv = get_conf_intervals(coefs,valid)

# %%
for i in range(0,len(valid)):
    print('Feature: {}'.format(valid[i])) 
    print('mean coefficient: {}'.format(conf_intv[i][0]))
    print('confidence interval: {}'.format(conf_intv[i][1]))
    if (conf_intv[i][0] >= conf_intv[i][1][0]) and (conf_intv[i][0] <= conf_intv[i][1][1]):
        print("Accept Hypothesis")
    else:
        print("Reject Hypothesis")
    print('-------------------------------------')
